# %% [markdown]
# # Default notebook
#
# This default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
# Set default catalog and schema
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"USE SCHEMA {schema}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Set default catalog and schema
# ----> 2 catalog = dbutils.widgets.get("catalog")
#       3 schema = dbutils.widgets.get("schema")
#       4 spark.sql(f"USE CATALOG {catalog}")
#
# NameError: name 'dbutils' is not defined

# %%
import sys

sys.path.append("../src")
from ipl_analysis import taxis

taxis.find_all_taxis().show(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       3 sys.path.append("../src")
# ----> 4 from ipl_analysis import taxis
#       6 taxis.find_all_taxis().show(10)
#
# File ~/Projects/ipl_analysis/src/ipl_analysis/taxis.py:1
# ----> 1 from databricks.sdk.runtime import spark
#       2 from pyspark.sql import DataFrame
#       5 def find_all_taxis() -> DataFrame:
#
# ModuleNotFoundError: No module named 'databricks'
